# %%
# %matplotlib inline

# Import packages
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
# Load datasets
sim1 = pd.read_csv('data/Sim 1.txt')
sim2 = pd.read_csv('data/Sim 2.txt')
sim3 = pd.read_csv('data/Sim 3.txt')
sim4 = pd.read_csv('data/Sim 4.txt')
sim5 = pd.read_csv('data/Sim 5.txt')
sim6 = pd.read_csv('data/Sim 6.txt')
sim7 = pd.read_csv('data/Sim 7.txt')
sim8 = pd.read_csv('data/Sim 8.txt')
sim9 = pd.read_csv('data/Sim 9.txt')
sim10 = pd.read_csv('data/Sim 10.txt')
sim11 = pd.read_csv('data/Sim 11.txt')
sim12 = pd.read_csv('data/Sim 12.txt')
sim13 = pd.read_csv('data/Sim 13.txt')
sim14 = pd.read_csv('data/Sim 14.txt')
sim15 = pd.read_csv('data/Sim 15.txt')
sim16 = pd.read_csv('data/Sim 16.txt')

# %%
# Figure Population simulation with different ventilation rates
f, ax = plt.subplots(4, figsize=(15, 8))
plt.subplot(2,2,1)
plt.plot(sim6.index, sim6.Susceptible, label='$A = 0$')
plt.plot(sim1.index, sim1.Susceptible, label='$A = 0.01$')
plt.plot(sim2.index, sim2.Susceptible, label='$A = 0.5$')
plt.plot(sim3.index, sim3.Susceptible, label='$A = 1$')
plt.plot(sim4.index, sim4.Susceptible, label='$A = 3$')
plt.plot(sim5.index, sim5.Susceptible, label='$A = 5$')
plt.plot(sim7.index, sim7.Susceptible, label='$A = 10$')
plt.title('Susceptible citizen count')
plt.ylabel('Citizen count')
plt.xlabel('Hours')
plt.legend()
plt.subplot(2,2,2)
plt.plot(sim6.index, sim6.Exposed, label='$A = 0$')
plt.plot(sim1.index, sim1.Exposed, label='$A = 0.01$')
plt.plot(sim2.index, sim2.Exposed, label='$A = 0.5$')
plt.plot(sim3.index, sim3.Exposed, label='$A = 1$')
plt.plot(sim4.index, sim4.Exposed, label='$A = 3$')
plt.plot(sim5.index, sim5.Exposed, label='$A = 5$')
plt.plot(sim7.index, sim7.Exposed, label='$A = 10$')
plt.title('Exposed citizen count')
plt.ylabel('Citizen count')
plt.xlabel('Hours')
plt.legend()
plt.subplot(2,2,3)
plt.plot(sim6.index, sim6.Infected, label='$A = 0$')
plt.plot(sim1.index, sim1.Infected, label='$A = 0.01$')
plt.plot(sim2.index, sim2.Infected, label='$A = 0.5$')
plt.plot(sim3.index, sim3.Infected, label='$A = 1$')
plt.plot(sim4.index, sim4.Infected, label='$A = 3$')
plt.plot(sim5.index, sim5.Infected, label='$A = 5$')
plt.plot(sim7.index, sim7.Infected, label='$A = 10$')
plt.title('Infected citizen count')
plt.ylabel('Citizen count')
plt.xlabel('Hours')
plt.legend()
plt.subplot(2,2,4)
plt.plot(sim6.index, sim6.Recovered, label='$A = 0$')
plt.plot(sim1.index, sim1.Recovered, label='$A = 0.01$')
plt.plot(sim2.index, sim2.Recovered, label='$A = 0.5$')
plt.plot(sim3.index, sim3.Recovered, label='$A = 1$')
plt.plot(sim4.index, sim4.Recovered, label='$A = 3$')
plt.plot(sim5.index, sim5.Recovered, label='$A = 5$')
plt.plot(sim7.index, sim7.Recovered, label='$A = 10$')
plt.title('Recovered citizen count')
plt.ylabel('Citizen count')
plt.xlabel('Hours')
plt.legend()
plt.tight_layout()

# %%
# Figure Population simulation with different treatment dropout rates
f, ax = plt.subplots(4, figsize=(15, 8))
plt.subplot(2,2,1)
plt.plot(sim8.index, sim8.Susceptible, label='$D_r = 0$')
plt.plot(sim9.index, sim9.Susceptible, label='$D_r = 0.2$')
plt.plot(sim10.index, sim10.Susceptible, label='$D_r = 0.4$')
plt.plot(sim11.index, sim11.Susceptible, label='$D_r = 0.6$')
plt.plot(sim12.index, sim12.Susceptible, label='$D_r = 0.8$')
plt.plot(sim13.index, sim13.Susceptible, label='$D_r = 1.0$')
plt.title('Susceptible citizen count')
plt.ylabel('Citizen count')
plt.xlabel('Hours')
plt.legend()
plt.subplot(2,2,2)
plt.plot(sim8.index, sim8.Exposed, label='$D_r = 0$')
plt.plot(sim9.index, sim9.Exposed, label='$D_r = 0.2$')
plt.plot(sim10.index, sim10.Exposed, label='$D_r = 0.4$')
plt.plot(sim11.index, sim11.Exposed, label='$D_r = 0.6$')
plt.plot(sim12.index, sim12.Exposed, label='$D_r = 0.8$')
plt.plot(sim13.index, sim13.Exposed, label='$D_r = 1.0$')
plt.title('Exposed citizen count')
plt.ylabel('Citizen count')
plt.xlabel('Hours')
plt.legend()
plt.subplot(2,2,3)
plt.plot(sim8.index, sim8.Infected, label='$D_r = 0$')
plt.plot(sim9.index, sim9.Infected, label='$D_r = 0.2$')
plt.plot(sim10.index, sim10.Infected, label='$D_r = 0.4$')
plt.plot(sim11.index, sim11.Infected, label='$D_r = 0.6$')
plt.plot(sim12.index, sim12.Infected, label='$D_r = 0.8$')
plt.plot(sim13.index, sim13.Infected, label='$D_r = 1.0$')
plt.title('Infected citizen count')
plt.ylabel('Citizen count')
plt.xlabel('Hours')
plt.legend()
plt.subplot(2,2,4)
plt.plot(sim8.index, sim8.Recovered, label='$D_r = 0$')
plt.plot(sim9.index, sim9.Recovered, label='$D_r = 0.2$')
plt.plot(sim10.index, sim10.Recovered, label='$D_r = 0.4$')
plt.plot(sim11.index, sim11.Recovered, label='$D_r = 0.6$')
plt.plot(sim12.index, sim12.Recovered, label='$D_r = 0.8$')
plt.plot(sim13.index, sim13.Recovered, label='$D_r = 1.0$')
plt.title('Recovered citizen count')
plt.ylabel('Citizen count')
plt.xlabel('Hours')
plt.legend()
plt.tight_layout()

# %%
# Figure Population simulation with different immunodepression shares
f, ax = plt.subplots(4, figsize=(15, 8))
plt.subplot(2,2,1)
plt.plot(sim14.index, sim14.Susceptible, label='$I_r = 0$')
plt.plot(sim15.index, sim15.Susceptible, label='$I_r = 0.2$')
plt.plot(sim16.index, sim16.Susceptible, label='$I_r = 0.4$')
plt.title('Susceptible citizen count')
plt.ylabel('Citizen count')
plt.xlabel('Hours')
plt.legend()
plt.subplot(2,2,2)
plt.plot(sim14.index, sim14.Exposed, label='$I_r = 0$')
plt.plot(sim15.index, sim15.Exposed, label='$I_r = 0.2$')
plt.plot(sim16.index, sim16.Exposed, label='$I_r = 0.4$')
plt.title('Exposed citizen count')
plt.ylabel('Citizen count')
plt.xlabel('Hours')
plt.legend()
plt.subplot(2,2,3)
plt.plot(sim14.index, sim14.Infected, label='$I_r = 0$')
plt.plot(sim15.index, sim15.Infected, label='$I_r = 0.2$')
plt.plot(sim16.index, sim16.Infected, label='$I_r = 0.4$')
plt.title('Infected citizen count')
plt.ylabel('Citizen count')
plt.xlabel('Hours')
plt.legend()
plt.subplot(2,2,4)
plt.plot(sim14.index, sim14.Recovered, label='$I_r = 0$')
plt.plot(sim15.index, sim15.Recovered, label='$I_r = 0.2$')
plt.plot(sim16.index, sim16.Recovered, label='$I_r = 0.4$')
plt.title('Recovered citizen count')
plt.ylabel('Citizen count')
plt.xlabel('Hours')
plt.legend()
plt.tight_layout()
