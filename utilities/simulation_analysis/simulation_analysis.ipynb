# %%
# %matplotlib inline

# Import packages
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load datasets
sim1 = pd.read_csv('data/Sim 1.txt')
sim2 = pd.read_csv('data/Sim 2.txt')
sim3 = pd.read_csv('data/Sim 3.txt')
sim4 = pd.read_csv('data/Sim 4.txt')
sim5 = pd.read_csv('data/Sim 5.txt')
sim6 = pd.read_csv('data/Sim 6.txt')
sim7 = pd.read_csv('data/Sim 7.txt')
sim8 = pd.read_csv('data/Sim 8.txt')
sim9 = pd.read_csv('data/Sim 9.txt')
sim10 = pd.read_csv('data/Sim 10.txt')
sim11 = pd.read_csv('data/Sim 11.txt')
sim12 = pd.read_csv('data/Sim 12.txt')
sim13 = pd.read_csv('data/Sim 13.txt')
sim14 = pd.read_csv('data/Sim 14.txt')
sim15 = pd.read_csv('data/Sim 15.txt')
sim16 = pd.read_csv('data/Sim 16.txt')

# %%
sim1.describe()
# Out:
#         Susceptible       Exposed      Infected     Recovered  OnTreatment
# count  26280.000000  26280.000000  26280.000000  26280.000000  26280.00000
# mean    2828.170852   1863.354224     24.417846    168.002968     85.05411
# std      221.769741     72.725576      4.829718    130.808802     26.43624
# min     2515.000000   1667.000000      2.000000      0.000000      0.00000
# 25%     2634.000000   1825.000000     21.000000     32.000000     82.00000
# 50%     2799.000000   1891.000000     25.000000    162.000000     94.00000
# 75%     2998.000000   1915.000000     28.000000    296.000000    101.00000
# max     3300.000000   1965.000000     38.000000    360.000000    115.00000

# %%
f, ax = plt.subplots(1, figsize=(10, 8))
plt.plot(sim6.index, sim6.Susceptible, label='V = 0')
plt.plot(sim1.index, sim1.Susceptible, label='V = 0.01')
plt.plot(sim2.index, sim2.Susceptible, label='V = 0.5')
plt.plot(sim3.index, sim3.Susceptible, label='V = 1')
plt.plot(sim4.index, sim4.Susceptible, label='V = 3')
plt.plot(sim5.index, sim5.Susceptible, label='V = 5')
plt.plot(sim7.index, sim7.Susceptible, label='V = 10')
plt.legend()

# %%
f, ax = plt.subplots(1, figsize=(10, 8))
plt.plot(sim6.index, sim6.Exposed, label='V = 0')
plt.plot(sim1.index, sim1.Exposed, label='V = 0.01')
plt.plot(sim2.index, sim2.Exposed, label='V = 0.5')
plt.plot(sim3.index, sim3.Exposed, label='V = 1')
plt.plot(sim4.index, sim4.Exposed, label='V = 3')
plt.plot(sim5.index, sim5.Exposed, label='V = 5')
plt.plot(sim7.index, sim7.Exposed, label='V = 10')
plt.legend()

# %%
f, ax = plt.subplots(1, figsize=(10, 8))
plt.plot(sim6.index, sim6.Infected, label='V = 0')
plt.plot(sim1.index, sim1.Infected, label='V = 0.01')
plt.plot(sim2.index, sim2.Infected, label='V = 0.5')
plt.plot(sim3.index, sim3.Infected, label='V = 1')
plt.plot(sim4.index, sim4.Infected, label='V = 3')
plt.plot(sim5.index, sim5.Infected, label='V = 5')
plt.plot(sim7.index, sim7.Infected, label='V = 10')
plt.legend()

# %%
f, ax = plt.subplots(1, figsize=(10, 8))
plt.plot(sim6.index, sim6.Recovered, label='V = 0')
plt.plot(sim1.index, sim1.Recovered, label='V = 0.01')
plt.plot(sim2.index, sim2.Recovered, label='V = 0.5')
plt.plot(sim3.index, sim3.Recovered, label='V = 1')
plt.plot(sim4.index, sim4.Recovered, label='V = 3')
plt.plot(sim5.index, sim5.Recovered, label='V = 5')
plt.plot(sim7.index, sim7.Recovered, label='V = 10')
plt.legend()

# %%
f, ax = plt.subplots(1, figsize=(10, 8))
plt.plot(sim6.index, sim6.OnTreatment, label='V = 0')
plt.plot(sim1.index, sim1.OnTreatment, label='V = 0.01')
plt.plot(sim2.index, sim2.OnTreatment, label='V = 0.5')
plt.plot(sim3.index, sim3.OnTreatment, label='V = 1')
plt.plot(sim4.index, sim4.OnTreatment, label='V = 3')
plt.plot(sim5.index, sim5.OnTreatment, label='V = 5')
plt.plot(sim7.index, sim7.OnTreatment, label='V = 10')
plt.legend()

# %%
f, ax = plt.subplots(1, figsize=(10, 8))
plt.plot(sim8.index, sim8.Susceptible, label='D_r = 0')
plt.plot(sim9.index, sim9.Susceptible, label='D_r = 0.2')
plt.plot(sim10.index, sim10.Susceptible, label='D_r = 0.4')
plt.plot(sim11.index, sim11.Susceptible, label='D_r = 0.6')
plt.plot(sim12.index, sim12.Susceptible, label='D_r = 0.8')
plt.plot(sim13.index, sim13.Susceptible, label='D_r = 1.0')
plt.legend()

# %%
f, ax = plt.subplots(1, figsize=(10, 8))
plt.plot(sim8.index, sim8.Exposed, label='D_r = 0')
plt.plot(sim9.index, sim9.Exposed, label='D_r = 0.2')
plt.plot(sim10.index, sim10.Exposed, label='D_r = 0.4')
plt.plot(sim11.index, sim11.Exposed, label='D_r = 0.6')
plt.plot(sim12.index, sim12.Exposed, label='D_r = 0.8')
plt.plot(sim13.index, sim13.Exposed, label='D_r = 1.0')
plt.legend()

# %%
f, ax = plt.subplots(1, figsize=(10, 8))
plt.plot(sim8.index, sim8.Infected, label='D_r = 0')
plt.plot(sim9.index, sim9.Infected, label='D_r = 0.2')
plt.plot(sim10.index, sim10.Infected, label='D_r = 0.4')
plt.plot(sim11.index, sim11.Infected, label='D_r = 0.6')
plt.plot(sim12.index, sim12.Infected, label='D_r = 0.8')
plt.plot(sim13.index, sim13.Infected, label='D_r = 1.0')
plt.legend()

# %%
f, ax = plt.subplots(1, figsize=(10, 8))
plt.plot(sim8.index, sim8.Recovered, label='D_r = 0')
plt.plot(sim9.index, sim9.Recovered, label='D_r = 0.2')
plt.plot(sim10.index, sim10.Recovered, label='D_r = 0.4')
plt.plot(sim11.index, sim11.Recovered, label='D_r = 0.6')
plt.plot(sim12.index, sim12.Recovered, label='D_r = 0.8')
plt.plot(sim13.index, sim13.Recovered, label='D_r = 1.0')
plt.legend()

# %%
f, ax = plt.subplots(1, figsize=(10, 8))
plt.plot(sim8.index, sim8.OnTreatment, label='D_r = 0')
plt.plot(sim9.index, sim9.OnTreatment, label='D_r = 0.2')
plt.plot(sim10.index, sim10.OnTreatment, label='D_r = 0.4')
plt.plot(sim11.index, sim11.OnTreatment, label='D_r = 0.6')
plt.plot(sim12.index, sim12.OnTreatment, label='D_r = 0.8')
plt.plot(sim13.index, sim13.OnTreatment, label='D_r = 1.0')
plt.legend()

# %%
f, ax = plt.subplots(1, figsize=(10, 8))
plt.plot(sim14.index, sim14.Susceptible, label='Im_r = 0')
plt.plot(sim15.index, sim15.Susceptible, label='Im_r = 0.1')
plt.plot(sim16.index, sim16.Susceptible, label='Im_r = 0.25')
plt.legend()

# %%
f, ax = plt.subplots(1, figsize=(10, 8))
plt.plot(sim14.index, sim14.Exposed, label='Im_r = 0')
plt.plot(sim15.index, sim15.Exposed, label='Im_r = 0.1')
plt.plot(sim16.index, sim16.Exposed, label='Im_r = 0.25')
plt.legend()

# %%
f, ax = plt.subplots(1, figsize=(10, 8))
plt.plot(sim14.index, sim14.Infected, label='Im_r = 0')
plt.plot(sim15.index, sim15.Infected, label='Im_r = 0.1')
plt.plot(sim16.index, sim16.Infected, label='Im_r = 0.25')
plt.legend()

# %%
f, ax = plt.subplots(1, figsize=(10, 8))
plt.plot(sim14.index, sim14.Recovered, label='Im_r = 0')
plt.plot(sim15.index, sim15.Recovered, label='Im_r = 0.1')
plt.plot(sim16.index, sim16.Recovered, label='Im_r = 0.25')
plt.legend()

# %%
f, ax = plt.subplots(1, figsize=(10, 8))
plt.plot(sim14.index, sim14.OnTreatment, label='Im_r = 0')
plt.plot(sim15.index, sim15.OnTreatment, label='Im_r = 0.1')
plt.plot(sim16.index, sim16.OnTreatment, label='Im_r = 0.25')
plt.legend()
